# %% [markdown]
# Import Library

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("C://Users//GARGI KAR//Desktop//Personal Projects//Youtube Scrapper//Y-tube-Channels.xlsx")

# %% [markdown]
# DATA PREPROCESSING

# %%
df.head()
# Out:
#   Rank Grade                Channel name Video Uploads Subscribers  \
# 0  1st  A++                       Zee TV         82757    18752951
# 1  2nd  A++                     T-Series         12661    61196302
# 2  3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3  4th  A++                    SET India         27323    31180559
# 4  5th  A++                          WWE         36756    32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %%
df.tail()
# Out:
#          Rank Grade       Channel name Video Uploads Subscribers  Video views
# 4995  4,996th   B+      Uras Benlioğlu           706     2072942    441202795
# 4996  4,997th   B+   HI-TECH MUSIC LTD           797     1055091    377331722
# 4997  4,998th   B+         Mastersaint           110     3265735    311758426
# 4998  4,999th   B+      Bruce McIntosh          3475       32990     14563764
# 4999  5,000th   B+           SehatAQUA           254       21172     73312511

# %%
df.shape
# Out:
# (5000, 6)

# %%
df.columns
# Out:
# Index(['Rank', 'Grade', 'Channel name', 'Video Uploads', 'Subscribers',
#        'Video views'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Rank             object
# Grade            object
# Channel name     object
# Video Uploads    object
# Subscribers      object
# Video views       int64
# dtype: object

# %%
df['Channel name'].unique()
# Out:
# array(['Zee TV', 'T-Series', 'Cocomelon - Nursery Rhymes', ...,
#        'Mastersaint', 'Bruce McIntosh', 'SehatAQUA'], dtype=object)

# %%
df.nunique()
# Out:
# Rank             5000
# Grade               6
# Channel name     4993
# Video Uploads    2286
# Subscribers      4612
# Video views      5000
# dtype: int64

# %%
df.describe()
# Out:
#          Video views
# count        5000.00
# mean   1071449400.15
# std    2003843972.12
# min            75.00
# 25%     186232945.75
# 50%     482054780.00
# 75%    1124367826.75
# max   47548839843.00

# %%
df["Channel name"].value_counts()
# Out:
# Channel name
# Thơ Nguyễn                 2
# Various Artists - Topic    2
# Learn Colors For Kids      2
# Super Kids                 2
# Funny Vines                2
#                           ..
# MeLlamanFredy              1
# Soosloli PoP               1
# SBS 뉴스                     1
# 酷酷的文                       1
# SehatAQUA                  1
# Name: count, Length: 4993, dtype: int64

# %%
df.describe()
# Out:
#          Video views
# count        5000.00
# mean   1071449400.15
# std    2003843972.12
# min            75.00
# 25%     186232945.75
# 50%     482054780.00
# 75%    1124367826.75
# max   47548839843.00

# %% [markdown]
# Converting exponential part into decimal

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
df.describe()
# Out:
#          Video views
# count        5000.00
# mean   1071449400.15
# std    2003843972.12
# min            75.00
# 25%     186232945.75
# 50%     482054780.00
# 75%    1124367826.75
# max   47548839843.00

# %% [markdown]
# Replace "--" to NaN

# %%
df.head(50)
# Out:
#     Rank Grade                Channel name Video Uploads Subscribers  \
# 0    1st  A++                       Zee TV         82757    18752951
# 1    2nd  A++                     T-Series         12661    61196302
# 2    3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3    4th  A++                    SET India         27323    31180559
# 4    5th  A++                          WWE         36756    32852346
# 5    6th  A++                   Movieclips         30243    17149705
# 6    7th  A++                   netd müzik          8500    11373567
# 7    8th  A++        ABS-CBN Entertainment        100147    12149206
# 8    9th  A++              Ryan ToysReview          1140    16082927
# 9   10th  A++                  Zee Marathi         74607     2841811
# 10  11th   A+              5-Minute Crafts          2085    33492951
# 11  12th   A+              Canal KondZilla           822    39409726
# 12  13th   A+             Like Nastya Vlog           150     7662886
# ...

# %%
df=df.replace("--",np.nan,regex=True)

# %%
df.head(50)
# Out:
#     Rank Grade                Channel name  Video Uploads  Subscribers  \
# 0    1st  A++                       Zee TV       82757.00  18752951.00
# 1    2nd  A++                     T-Series       12661.00  61196302.00
# 2    3rd  A++   Cocomelon - Nursery Rhymes         373.00  19238251.00
# 3    4th  A++                    SET India       27323.00  31180559.00
# 4    5th  A++                          WWE       36756.00  32852346.00
# 5    6th  A++                   Movieclips       30243.00  17149705.00
# 6    7th  A++                   netd müzik        8500.00  11373567.00
# 7    8th  A++        ABS-CBN Entertainment      100147.00  12149206.00
# 8    9th  A++              Ryan ToysReview        1140.00  16082927.00
# 9   10th  A++                  Zee Marathi       74607.00   2841811.00
# 10  11th   A+              5-Minute Crafts        2085.00  33492951.00
# 11  12th   A+              Canal KondZilla         822.00  39409726.00
# ...

# %% [markdown]
# Checking the missing values in the dataset.
#
# Heatmaps are a powerful way to visualize patterns in data. In this case, the heatmap will show the distribution and patterns of missing values across different columns of the DataFrame. It can help you quickly identify which columns or areas of your dataset have missing data, which can be valuable for data preprocessing and analysis.

# %%
df.isnull().sum()
# Out:
# Rank               0
# Grade              0
# Channel name       0
# Video Uploads      6
# Subscribers      387
# Video views        0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.dropna(axis=0 , inplace=True)
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# Remove the string values from Rank Column

# %%
df
# Out:
#          Rank Grade                Channel name  Video Uploads  Subscribers  \
# 0         1st  A++                       Zee TV       82757.00  18752951.00
# 1         2nd  A++                     T-Series       12661.00  61196302.00
# 2         3rd  A++   Cocomelon - Nursery Rhymes         373.00  19238251.00
# 3         4th  A++                    SET India       27323.00  31180559.00
# 4         5th  A++                          WWE       36756.00  32852346.00
# ...       ...   ...                         ...            ...          ...
# 4995  4,996th   B+               Uras Benlioğlu         706.00   2072942.00
# 4996  4,997th   B+            HI-TECH MUSIC LTD         797.00   1055091.00
# 4997  4,998th   B+                  Mastersaint         110.00   3265735.00
# 4998  4,999th   B+               Bruce McIntosh        3475.00     32990.00
# 4999  5,000th   B+                    SehatAQUA         254.00     21172.00
#
#       Video views
# 0     20869786591
# ...

# %%
df["Rank"] = df["Rank"].str[0:-2]
df.head()
# Out:
#   Rank Grade                Channel name  Video Uploads  Subscribers  \
# 0    1  A++                       Zee TV       82757.00  18752951.00
# 1    2  A++                     T-Series       12661.00  61196302.00
# 2    3  A++   Cocomelon - Nursery Rhymes         373.00  19238251.00
# 3    4  A++                    SET India       27323.00  31180559.00
# 4    5  A++                          WWE       36756.00  32852346.00
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %%
df.tail()
# Out:
#        Rank Grade       Channel name  Video Uploads  Subscribers  Video views
# 4995  4,996   B+      Uras Benlioğlu         706.00   2072942.00    441202795
# 4996  4,997   B+   HI-TECH MUSIC LTD         797.00   1055091.00    377331722
# 4997  4,998   B+         Mastersaint         110.00   3265735.00    311758426
# 4998  4,999   B+      Bruce McIntosh        3475.00     32990.00     14563764
# 4999  5,000   B+           SehatAQUA         254.00     21172.00     73312511

# %% [markdown]
# Removing Commas from Rank Coloumns

# %%
df["Rank"] = df["Rank"].str.replace(",",'')
df.tail()
# Out:
#       Rank Grade       Channel name  Video Uploads  Subscribers  Video views
# 4995  4996   B+      Uras Benlioğlu         706.00   2072942.00    441202795
# 4996  4997   B+   HI-TECH MUSIC LTD         797.00   1055091.00    377331722
# 4997  4998   B+         Mastersaint         110.00   3265735.00    311758426
# 4998  4999   B+      Bruce McIntosh        3475.00     32990.00     14563764
# 4999  5000   B+           SehatAQUA         254.00     21172.00     73312511

# %%
df.dtypes
# Out:
# Rank              object
# Grade             object
# Channel name      object
# Video Uploads    float64
# Subscribers      float64
# Video views        int64
# dtype: object

# %% [markdown]
# Changing the datatype of Rank and Subscribers Columns.

# %%
df["Rank"] = df["Rank"].astype("int")
df["Subscribers"] = df["Subscribers"].astype("int")
df.dtypes
# Out:
# Rank               int32
# Grade             object
# Channel name      object
# Video Uploads    float64
# Subscribers        int32
# Video views        int64
# dtype: object

# %% [markdown]
# Data Cleaning of Grade Column

# %%
df["Grade"].unique()
# Out:
# array(['A++ ', 'A+ ', 'A ', 'A- ', 'B+ '], dtype=object)

# %%
df["Grade"]=df["Grade"].map({'A++ ':5 ,'A+':4 , 'A':3 , 'A-':2 , 'B+ ':1})

# %%
df.head()
# Out:
#    Rank  Grade                Channel name  Video Uploads  Subscribers  \
# 0     1   5.00                      Zee TV       82757.00     18752951
# 1     2   5.00                    T-Series       12661.00     61196302
# 2     3   5.00  Cocomelon - Nursery Rhymes         373.00     19238251
# 3     4   5.00                   SET India       27323.00     31180559
# 4     5   5.00                         WWE       36756.00     32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %% [markdown]
# Find Out the Maximum Number of "Videos Upload"

# %%
df.columns
# Out:
# Index(['Rank', 'Grade', 'Channel name', 'Video Uploads', 'Subscribers',
#        'Video views'],
#       dtype='object')

# %%
df.sort_values(by='Video Uploads',ascending=False).head()
# Out:
#       Rank  Grade Channel name  Video Uploads  Subscribers  Video views
# 3453  3454   1.00   AP Archive      422326.00       746325    548619569
# 1149  1150    NaN     YTN NEWS      355996.00       820108   1640347646
# 2223  2224   1.00    SBS Drama      335521.00      1418619   1565758044
# 323    324    NaN     GMA News      269065.00      2599175   2786949164
# 2956  2957   1.00          MLB      267649.00      1434206   1329206392

# %% [markdown]
# Finding Corelation
#
# The correlation matrix shows how each numeric column is related to every other numeric column in terms of their linear relationships. It calculates the Pearson correlation coefficient, which ranges from -1 to 1, indicating the strength and direction of the correlation between two variables. Positive values indicate positive correlation, negative values indicate negative correlation, and values close to 0 indicate weak or no correlation.
#
# The printed output will display a square matrix where each cell represents the correlation coefficient between two numeric columns. The matrix is symmetric along its diagonal, as the correlation between A and B is the same as the correlation between B and A. The values in the matrix will range between -1 and 1, with diagonal elements being 1 (since a variable has a perfect correlation with itself).
#
# By examining the correlation matrix, you can gain insights into the relationships between different numeric variables in your dataset. It can help you understand how changes in one variable are associated with changes in another, which is useful for tasks such as feature selection, dimensionality reduction, and identifying potential multicollinearity in regression analysis.

# %%
numeric_columns = df.select_dtypes(include=['number'])

# Calculate the correlation matrix
correlation_matrix = numeric_columns.corr()

# Display the correlation matrix
print(correlation_matrix)
# Out:
#                Rank  Grade  Video Uploads  Subscribers  Video views
# Rank           1.00  -0.24          -0.07        -0.38        -0.40
# Grade         -0.24   1.00           0.13         0.49         0.80
# Video Uploads -0.07   0.13           1.00         0.01         0.09
# Subscribers   -0.38   0.49           0.01         1.00         0.79
# Video views   -0.40   0.80           0.09         0.79         1.00

# %% [markdown]
# Finding which Grade has the maximun number of video upload

# %%
sns.barplot(x = "Grade", y = "Video Uploads", data = df)
# Out:
# <Axes: xlabel='Grade', ylabel='Video Uploads'>

# %% [markdown]
# Finding which Grade has highest number of views

# %%
sns.barplot(x = "Grade", y = "Video views", data = df)
# Out:
# <Axes: xlabel='Grade', ylabel='Video views'>
